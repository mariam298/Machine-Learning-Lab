# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# %%
df=pd.read_csv("Iris.csv")
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
y=list(df["species"])

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
le.fit(y)
y=le.transform(y)

# %%
features= ["sepal_length","sepal_width","petal_length","petal_width"]
X = pd.get_dummies(df[features])
X
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.33, random_state=42)

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
y_pred = gnb.fit(X_train, y_train).predict(X_test)
print(y_pred)
# Out:
# [1 0 2 1 1 0 1 2 1 1 2 0 0 0 0 2 2 1 1 2 0 2 0 2 2 2 2 2 0 0 0 0 1 0 0 2 1
#  0 0 0 2 1 1 0 0 1 1 2 1 2]

# %%
from sklearn.metrics import ConfusionMatrixDisplay
ConfusionMatrixDisplay.from_estimator(gnb, X_test, y_test)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test, y_pred, normalize=True)
# Out:
# 0.96

# %%
from sklearn.metrics import ConfusionMatrixDisplay
ConfusionMatrixDisplay.from_estimator(gnb, X_test, y_test)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test, y_pred, normalize=True)
# Out:
# 0.96

# %%
def categorize(a):
    if a == 0.0:
        return('setosa')
    if a == 1.0:
        return('versicolor')
    return('virginica')
df['Species'] = df['species'].apply(categorize)

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=1)
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=1)

# %%
prediction = knn.predict(X_test)
prediction
# Out:
# array([1, 0, 2, 1, 1, 0, 1, 2, 1, 1, 2, 0, 0, 0, 0, 1, 2, 1, 1, 2, 0, 2,
#        0, 2, 2, 2, 2, 2, 0, 0, 0, 0, 1, 0, 0, 2, 1, 0, 0, 0, 2, 1, 1, 0,
#        0, 1, 1, 2, 1, 2])

# %%
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy * 100:.2f}%")
# Out:
# Accuracy: 96.00%

# %%
import numpy as np
from sklearn.datasets import load_iris

# Load the Iris dataset
iris = load_iris()

# Display the target names
print(iris.target_names)
# Out:
# ['setosa' 'versicolor' 'virginica']

# %%
# Print correct predictions
print("Correct Predictions:")
for i in range(len(y_test)):
    if y_pred[i] == y_test[i]:
        print(f"Sample {i+1}: Predicted = {iris.target_names[y_pred[i]]}, Actual = {iris.target_names[y_test[i]]}")

# Print wrong predictions
print("\nWrong Predictions:")
for i in range(len(y_test)):
    if y_pred[i] != y_test[i]:
        print(f"Sample {i+1}: Predicted = {iris.target_names[y_pred[i]]}, Actual = {iris.target_names[y_test[i]]}")
# Out:
# Correct Predictions:
# Sample 1: Predicted = versicolor, Actual = versicolor
# Sample 2: Predicted = setosa, Actual = setosa
# Sample 3: Predicted = virginica, Actual = virginica
# Sample 4: Predicted = versicolor, Actual = versicolor
# Sample 5: Predicted = versicolor, Actual = versicolor
# Sample 6: Predicted = setosa, Actual = setosa
# Sample 7: Predicted = versicolor, Actual = versicolor
# Sample 8: Predicted = virginica, Actual = virginica
# Sample 9: Predicted = versicolor, Actual = versicolor
# Sample 10: Predicted = versicolor, Actual = versicolor
# Sample 11: Predicted = virginica, Actual = virginica
# Sample 12: Predicted = setosa, Actual = setosa
# Sample 13: Predicted = setosa, Actual = setosa
# Sample 14: Predicted = setosa, Actual = setosa
# Sample 15: Predicted = setosa, Actual = setosa
# Sample 17: Predicted = virginica, Actual = virginica
# Sample 18: Predicted = versicolor, Actual = versicolor
# Sample 19: Predicted = versicolor, Actual = versicolor
# Sample 20: Predicted = virginica, Actual = virginica
# Sample 21: Predicted = setosa, Actual = setosa
# Sample 22: Predicted = virginica, Actual = virginica
# Sample 23: Predicted = setosa, Actual = setosa
# Sample 24: Predicted = virginica, Actual = virginica
# Sample 25: Predicted = virginica, Actual = virginica
# Sample 26: Predicted = virginica, Actual = virginica
# Sample 27: Predicted = virginica, Actual = virginica
# Sample 28: Predicted = virginica, Actual = virginica
# Sample 29: Predicted = setosa, Actual = setosa
# Sample 30: Predicted = setosa, Actual = setosa
# Sample 31: Predicted = setosa, Actual = setosa
# Sample 32: Predicted = setosa, Actual = setosa
# Sample 33: Predicted = versicolor, Actual = versicolor
# Sample 34: Predicted = setosa, Actual = setosa
# Sample 35: Predicted = setosa, Actual = setosa
# Sample 36: Predicted = virginica, Actual = virginica
# Sample 37: Predicted = versicolor, Actual = versicolor
# Sample 38: Predicted = setosa, Actual = setosa
# Sample 39: Predicted = setosa, Actual = setosa
# Sample 40: Predicted = setosa, Actual = setosa
# Sample 41: Predicted = virginica, Actual = virginica
# Sample 42: Predicted = versicolor, Actual = versicolor
# Sample 43: Predicted = versicolor, Actual = versicolor
# Sample 44: Predicted = setosa, Actual = setosa
# Sample 45: Predicted = setosa, Actual = setosa
# Sample 46: Predicted = versicolor, Actual = versicolor
# Sample 48: Predicted = virginica, Actual = virginica
# Sample 49: Predicted = versicolor, Actual = versicolor
# Sample 50: Predicted = virginica, Actual = virginica
#
# Wrong Predictions:
# Sample 16: Predicted = virginica, Actual = versicolor
# Sample 47: Predicted = versicolor, Actual = virginica
